# %% [markdown]
# ## import the library

# %%
import slampy
from trajectory_drawer import TrajectoryDrawer
import cv2
import numpy as np
import time
from utils import load_images_KITTI
import plotly.graph_objects as go

# %% [markdown]
# ## params
# the configuration attribute of the algorithm can be found in the setting.yaml file,
# you can change this file in order to execute different algorithm with different options
#
# **image_folder** is the root folder of images

# %%
image_folder = 'Dataset/image_02'
setting_file ='settings.yaml'

# %% [markdown]
# initialize the system with the **setting_file** and the type of the sensor in this case monocular

# %%
app = slampy.System(setting_file,slampy.Sensor.MONOCULAR)
# Out:
# the input sensor select is MONOCULAR

# %% [markdown]
# ## load the images
# in this example we use the KITTI dataset, the images is not provided you can download it , in utils.py is also provide the method for read the TUM images named **load_images_TUM**

# %%
image_filenames, timestamps = load_images_KITTI(image_folder)
num_images = len(image_filenames)

# %% [markdown]
# ## plot the trajcetory
#
# initialize the Trajcetory and plot the figure

# %%
drawer = TrajectoryDrawer(height=600)
fig = drawer.get_figure()
fig
# Out:
# FigureWidget({
#     'data': [],
#     'layout': {'height': 600,
#                'scene': {'aspectmode': 'manual',
# …

# %% [markdown]
# run the algorithm with the load dataset and compute the plot

# %%
print('images in the sequences {}'.format(num_images))
#initialize the figure and the array of coordinates
prec_camera_center = None
start_eye=-num_images /2
for idx in range(num_images):
    # load and convert to RGB image '
    name = image_filenames[idx]
    image = cv2.imread(name)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    if image is None:
        print("failed to load image at {0}".format(self.idx))
        exit
    t1 = time.time()
    state = app.process_image_mono(image,timestamps[idx])
    t2 = time.time()
    if state == slampy.State.OK:
        #compute and plot the trajecotry
        drawer.plot_trajcetory(app)
    #sleep the execution if the time is less than the image acquisition
    ttrack = t2 - t1
    t = 0
    if idx < num_images - 1:
        t = timestamps[idx + 1] - timestamps[idx]
    elif idx > 0:
        t = timestamps[idx] - timestamps[idx - 1]

    if ttrack < t:
        time.sleep(t - ttrack)
# Out:
# images in the sequences 108
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.00846359319985, 'y': -8.003905362682417, 'z': 1.2846733629703522},
#                'eye': {'x': -18.00846359319985, 'y': -13.003905362682417, 'z': -53.71532663702965},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.01505815424025, 'y': -7.999298627313692, 'z': 1.8204684555530548},
#                'eye': {'x': -18.01505815424025, 'y': -12.999298627313692, 'z': -53.179531544446945},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.02044370956719, 'y': -8.00354632968083, 'z': 2.447110414505005},
#                'eye': {'x': -18.02044370956719, 'y': -13.00354632968083, 'z': -52.552889585494995},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.0055146580562, 'y': -8.002857415471226, 'z': 0.6031708419322968},
#                'eye': {'x': -18.0055146580562, 'y': -13.002857415471226, 'z': -54.3968291580677},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.01052629109472, 'y': -8.0056655225344, 'z': 1.2014718353748322},
#                'eye': {'x': -18.01052629109472, 'y': -13.0056655225344, 'z': -53.79852816462517},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.015896636992693, 'y': -8.00884425174445, 'z': 1.7972086369991302},
#                'eye': {'x': -18.015896636992693, 'y': -13.00884425174445, 'z': -53.20279136300087},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.021685721352696, 'y': -8.01190929301083, 'z': 2.400202453136444},
#                'eye': {'x': -18.021685721352696, 'y': -13.01190929301083, 'z': -52.599797546863556},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.025101892650127, 'y': -8.01497526653111, 'z': 2.9972925782203674},
#                'eye': {'x': -18.025101892650127, 'y': -13.01497526653111, 'z': -52.00270742177963},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.030231898650527, 'y': -8.017451012507081, 'z': 3.5894981026649475},
#                'eye': {'x': -18.030231898650527, 'y': -13.017451012507081, 'z': -51.41050189733505},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.034646291285753, 'y': -8.02032509073615, 'z': 4.18469101190567},
#                'eye': {'x': -18.034646291285753, 'y': -13.02032509073615, 'z': -50.81530898809433},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.03941674903035, 'y': -8.022983426228166, 'z': 4.775393307209015},
#                'eye': {'x': -18.03941674903035, 'y': -13.022983426228166, 'z': -50.224606692790985},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.042899634689093, 'y': -8.025999987497926, 'z': 5.356682538986206},
#                'eye': {'x': -18.042899634689093, 'y': -13.025999987497926, 'z': -49.643317461013794},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.047369614243507, 'y': -8.029075438156724, 'z': 5.940296649932861},
#                'eye': {'x': -18.047369614243507, 'y': -13.029075438156724, 'z': -49.05970335006714},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.051639515906572, 'y': -8.031751349568367, 'z': 6.525105834007263},
#                'eye': {'x': -18.051639515906572, 'y': -13.031751349568367, 'z': -48.47489416599274},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.055052254348993, 'y': -8.034868720918894, 'z': 7.1156007051467896},
#                'eye': {'x': -18.055052254348993, 'y': -13.034868720918894, 'z': -47.88439929485321},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.05919959768653, 'y': -8.037886284291744, 'z': 7.692504525184631},
#                'eye': {'x': -18.05919959768653, 'y': -13.037886284291744, 'z': -47.30749547481537},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.063025631010532, 'y': -8.040842063724995, 'z': 8.28586220741272},
#                'eye': {'x': -18.063025631010532, 'y': -13.040842063724995, 'z': -46.71413779258728},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.067286275327206, 'y': -8.043768487870693, 'z': 8.857014775276184},
#                'eye': {'x': -18.067286275327206, 'y': -13.043768487870693, 'z': -46.142985224723816},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.0714193880558, 'y': -8.046813637018204, 'z': 9.438320398330688},
#                'eye': {'x': -18.0714193880558, 'y': -13.046813637018204, 'z': -45.56167960166931},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.074717722833157, 'y': -8.049228891730309, 'z': 9.999185800552368},
#                'eye': {'x': -18.074717722833157, 'y': -13.049228891730309, 'z': -45.00081419944763},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.07850344479084, 'y': -8.052198898047209, 'z': 10.590765476226807},
#                'eye': {'x': -18.07850344479084, 'y': -13.052198898047209, 'z': -44.40923452377319},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.081867426633835, 'y': -8.055134426802397, 'z': 11.15167498588562},
#                'eye': {'x': -18.081867426633835, 'y': -13.055134426802397, 'z': -43.84832501411438},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.085361778736115, 'y': -8.057974826544523, 'z': 11.74283742904663},
#                'eye': {'x': -18.085361778736115, 'y': -13.057974826544523, 'z': -43.25716257095337},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.087763488292694, 'y': -8.060924910008907, 'z': 12.310582399368286},
#                'eye': {'x': -18.087763488292694, 'y': -13.060924910008907, 'z': -42.689417600631714},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.09144277870655, 'y': -8.06398269534111, 'z': 12.893187999725342},
#                'eye': {'x': -18.09144277870655, 'y': -13.06398269534111, 'z': -42.10681200027466},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.093808822333813, 'y': -8.066907688975334, 'z': 13.456951379776001},
#                'eye': {'x': -18.093808822333813, 'y': -13.066907688975334, 'z': -41.543048620224},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.096874304115772, 'y': -8.070026606321335, 'z': 14.02937650680542},
#                'eye': {'x': -18.096874304115772, 'y': -13.070026606321335, 'z': -40.97062349319458},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.098809875547886, 'y': -8.0728192999959, 'z': 14.572204351425171},
#                'eye': {'x': -18.098809875547886, 'y': -13.0728192999959, 'z': -40.42779564857483},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.101312339305878, 'y': -8.075994350016117, 'z': 15.138753652572632},
#                'eye': {'x': -18.101312339305878, 'y': -13.075994350016117, 'z': -39.86124634742737},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.103196419775486, 'y': -8.079167164862156, 'z': 15.662992000579834},
#                'eye': {'x': -18.103196419775486, 'y': -13.079167164862156, 'z': -39.337007999420166},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.107077553868294, 'y': -8.082478195428848, 'z': 16.217963695526123},
#                'eye': {'x': -18.107077553868294, 'y': -13.082478195428848, 'z': -38.78203630447388},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.108261227607727, 'y': -8.085794061422348, 'z': 16.765122413635254},
#                'eye': {'x': -18.108261227607727, 'y': -13.085794061422348, 'z': -38.234877586364746},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.110326558351517, 'y': -8.088869772851467, 'z': 17.319347858428955},
#                'eye': {'x': -18.110326558351517, 'y': -13.088869772851467, 'z': -37.680652141571045},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.112314745783806, 'y': -8.091296464204788, 'z': 17.854373455047607},
#                'eye': {'x': -18.112314745783806, 'y': -13.091296464204788, 'z': -37.14562654495239},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.114708326756954, 'y': -8.094416342675686, 'z': 18.41437339782715},
#                'eye': {'x': -18.114708326756954, 'y': -13.094416342675686, 'z': -36.58562660217285},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.117304608225822, 'y': -8.097452200949192, 'z': 18.939536809921265},
#                'eye': {'x': -18.117304608225822, 'y': -13.097452200949192, 'z': -36.060463190078735},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.119469054043293, 'y': -8.100161157548428, 'z': 19.474884271621704},
#                'eye': {'x': -18.119469054043293, 'y': -13.100161157548428, 'z': -35.525115728378296},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.121867798268795, 'y': -8.103060059249401, 'z': 20.010898113250732},
#                'eye': {'x': -18.121867798268795, 'y': -13.103060059249401, 'z': -34.98910188674927},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.124246679246426, 'y': -8.105536632239819, 'z': 20.540645122528076},
#                'eye': {'x': -18.124246679246426, 'y': -13.105536632239819, 'z': -34.459354877471924},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.125913068652153, 'y': -8.108810141682625, 'z': 21.06632709503174},
#                'eye': {'x': -18.125913068652153, 'y': -13.108810141682625, 'z': -33.93367290496826},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.12797722220421, 'y': -8.111929044127464, 'z': 21.603524684906006},
#                'eye': {'x': -18.12797722220421, 'y': -13.111929044127464, 'z': -33.396475315093994},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.129501417279243, 'y': -8.11511318385601, 'z': 22.121968269348145},
#                'eye': {'x': -18.129501417279243, 'y': -13.11511318385601, 'z': -32.878031730651855},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.131927087903023, 'y': -8.1181058883667, 'z': 22.652175426483154},
#                'eye': {'x': -18.131927087903023, 'y': -13.1181058883667, 'z': -32.347824573516846},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.133905336260796, 'y': -8.120620787143707, 'z': 23.13654661178589},
#                'eye': {'x': -18.133905336260796, 'y': -13.120620787143707, 'z': -31.86345338821411},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.136143535375595, 'y': -8.12341994047165, 'z': 23.64628314971924},
#                'eye': {'x': -18.136143535375595, 'y': -13.12341994047165, 'z': -31.35371685028076},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.136984184384346, 'y': -8.126126885414124, 'z': 24.12693977355957},
#                'eye': {'x': -18.136984184384346, 'y': -13.126126885414124, 'z': -30.87306022644043},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.139873638749123, 'y': -8.128964364528656, 'z': 24.628112316131592},
#                'eye': {'x': -18.139873638749123, 'y': -13.128964364528656, 'z': -30.371887683868408},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.141519710421562, 'y': -8.132174253463745, 'z': 25.135679244995117},
#                'eye': {'x': -18.141519710421562, 'y': -13.132174253463745, 'z': -29.864320755004883},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.144012093544006, 'y': -8.134758740663528, 'z': 25.633573532104492},
#                'eye': {'x': -18.144012093544006, 'y': -13.134758740663528, 'z': -29.366426467895508},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.147124469280243, 'y': -8.137302115559578, 'z': 26.137831211090088},
#                'eye': {'x': -18.147124469280243, 'y': -13.137302115559578, 'z': -28.862168788909912},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.149681761860847, 'y': -8.140333592891693, 'z': 26.61466360092163},
#                'eye': {'x': -18.149681761860847, 'y': -13.140333592891693, 'z': -28.38533639907837},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.15117149055004, 'y': -8.143382906913757, 'z': 27.11799383163452},
#                'eye': {'x': -18.15117149055004, 'y': -13.143382906913757, 'z': -27.88200616836548},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.15477992594242, 'y': -8.14609844982624, 'z': 27.602052688598633},
#                'eye': {'x': -18.15477992594242, 'y': -13.14609844982624, 'z': -27.397947311401367},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.156064331531525, 'y': -8.148765623569489, 'z': 28.09584617614746},
#                'eye': {'x': -18.156064331531525, 'y': -13.148765623569489, 'z': -26.90415382385254},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.1586172580719, 'y': -8.151231274008751, 'z': 28.576812744140625},
#                'eye': {'x': -18.1586172580719, 'y': -13.151231274008751, 'z': -26.423187255859375},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.15969854593277, 'y': -8.153697088360786, 'z': 29.068636894226074},
#                'eye': {'x': -18.15969854593277, 'y': -13.153697088360786, 'z': -25.931363105773926},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.162094205617905, 'y': -8.156462833285332, 'z': 29.544553756713867},
#                'eye': {'x': -18.162094205617905, 'y': -13.156462833285332, 'z': -25.455446243286133},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.163488298654556, 'y': -8.158698290586472, 'z': 30.006186962127686},
#                'eye': {'x': -18.163488298654556, 'y': -13.158698290586472, 'z': -24.993813037872314},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.165721267461777, 'y': -8.160978242754936, 'z': 30.461127758026123},
#                'eye': {'x': -18.165721267461777, 'y': -13.160978242754936, 'z': -24.538872241973877},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.168614476919174, 'y': -8.162631824612617, 'z': 30.89115858078003},
#                'eye': {'x': -18.168614476919174, 'y': -13.162631824612617, 'z': -24.10884141921997},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.1702551394701, 'y': -8.16504193842411, 'z': 31.332759857177734},
#                'eye': {'x': -18.1702551394701, 'y': -13.16504193842411, 'z': -23.667240142822266},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.172100201249123, 'y': -8.167815819382668, 'z': 31.767337322235107},
#                'eye': {'x': -18.172100201249123, 'y': -13.167815819382668, 'z': -23.232662677764893},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.174170941114426, 'y': -8.169966876506805, 'z': 32.215681076049805},
#                'eye': {'x': -18.174170941114426, 'y': -13.169966876506805, 'z': -22.784318923950195},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.174990370869637, 'y': -8.17216731607914, 'z': 32.640109062194824},
#                'eye': {'x': -18.174990370869637, 'y': -13.17216731607914, 'z': -22.359890937805176},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.17701555788517, 'y': -8.174395620822906, 'z': 33.06430101394653},
#                'eye': {'x': -18.17701555788517, 'y': -13.174395620822906, 'z': -21.935698986053467},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.1789148747921, 'y': -8.176509752869606, 'z': 33.485026359558105},
#                'eye': {'x': -18.1789148747921, 'y': -13.176509752869606, 'z': -21.514973640441895},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.180257841944695, 'y': -8.178461387753487, 'z': 33.88434648513794},
#                'eye': {'x': -18.180257841944695, 'y': -13.178461387753487, 'z': -21.11565351486206},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.182351037859917, 'y': -8.180726185441017, 'z': 34.303486347198486},
#                'eye': {'x': -18.182351037859917, 'y': -13.180726185441017, 'z': -20.696513652801514},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.183631420135498, 'y': -8.18288853764534, 'z': 34.703688621520996},
#                'eye': {'x': -18.183631420135498, 'y': -13.18288853764534, 'z': -20.296311378479004},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.185812667012215, 'y': -8.184972003102303, 'z': 35.10369062423706},
#                'eye': {'x': -18.185812667012215, 'y': -13.184972003102303, 'z': -19.89630937576294},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.187887087464333, 'y': -8.18699511885643, 'z': 35.476276874542236},
#                'eye': {'x': -18.187887087464333, 'y': -13.18699511885643, 'z': -19.523723125457764},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.18944700062275, 'y': -8.18901114165783, 'z': 35.861172676086426},
#                'eye': {'x': -18.18944700062275, 'y': -13.18901114165783, 'z': -19.138827323913574},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.191474467515945, 'y': -8.191115841269493, 'z': 36.23515844345093},
#                'eye': {'x': -18.191474467515945, 'y': -13.191115841269493, 'z': -18.764841556549072},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.192892223596573, 'y': -8.192899227142334, 'z': 36.60646915435791},
#                'eye': {'x': -18.192892223596573, 'y': -13.192899227142334, 'z': -18.39353084564209},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.194285988807678, 'y': -8.194719806313515, 'z': 36.93596124649048},
#                'eye': {'x': -18.194285988807678, 'y': -13.194719806313515, 'z': -18.06403875350952},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.196343541145325, 'y': -8.196161851286888, 'z': 37.29037046432495},
#                'eye': {'x': -18.196343541145325, 'y': -13.196161851286888, 'z': -17.70962953567505},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.19767114520073, 'y': -8.198112234473228, 'z': 37.64524221420288},
#                'eye': {'x': -18.19767114520073, 'y': -13.198112234473228, 'z': -17.35475778579712},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.197760567069054, 'y': -8.199943289160728, 'z': 37.94966697692871},
#                'eye': {'x': -18.197760567069054, 'y': -13.199943289160728, 'z': -17.05033302307129},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.19944566488266, 'y': -8.201755538582802, 'z': 38.285229206085205},
#                'eye': {'x': -18.19944566488266, 'y': -13.201755538582802, 'z': -16.714770793914795},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.20014889538288, 'y': -8.203003287315369, 'z': 38.573100566864014},
#                'eye': {'x': -18.20014889538288, 'y': -13.203003287315369, 'z': -16.426899433135986},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.201110750436783, 'y': -8.204500451683998, 'z': 38.889288902282715},
#                'eye': {'x': -18.201110750436783, 'y': -13.204500451683998, 'z': -16.110711097717285},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.20222082734108, 'y': -8.206017076969147, 'z': 39.19894456863403},
#                'eye': {'x': -18.20222082734108, 'y': -13.206017076969147, 'z': -15.801055431365967},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.20306070148945, 'y': -8.20740133523941, 'z': 39.47884798049927},
#                'eye': {'x': -18.20306070148945, 'y': -13.20740133523941, 'z': -15.521152019500732},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.20494820177555, 'y': -8.20887216925621, 'z': 39.76362943649292},
#                'eye': {'x': -18.20494820177555, 'y': -13.20887216925621, 'z': -15.23637056350708},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
# layout.Scene({
#     'aspectmode': 'manual',
#     'aspectratio': {'x': 50, 'y': 50, 'z': 100},
#     'camera': {'center': {'x': -17.20682942867279, 'y': -8.210621297359467, 'z': 40.051026344299316},
#                'eye': {'x': -18.20682942867279, 'y': -13.210621297359467, 'z': -14.948973655700684},
#                'up': {'x': 0, 'y': 1, 'z': 0}},
#     'xaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'yaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False},
#     'zaxis': {'autorange': False, 'showgrid': False, 'showticklabels': False, 'visible': False, 'zeroline': False}
# })
